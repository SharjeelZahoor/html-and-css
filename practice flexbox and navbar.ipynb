# %% [markdown]
# <a href="https://colab.research.google.com/github/SharjeelZahoor/html-and-css/blob/main/practice%20flexbox%20and%20navbar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Practicing navbar and flexboxes using HTML and CSS.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta http-equiv="X-UA-Compatible" content="IE=edge">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>navbar with other items</title>
    <style>
    *{
        margin: 0;
        padding: 0;
    }
        .navbar{
            height: 60px;
        background-color: rgb(17, 16, 16);
        color: white;
        }
        ul{
            padding: 20px;
        }
        li{
            display: inline;
            margin: 10px;
            text-decoration: none;
            font-size: 20px;
            align-items: center;
        }
        .container{
            height: 35vh;
            width: 100vw;
            background-color: rgb(9, 68, 68);
        }


        .box1{
            height: 60vh;
            width: 40vw;
            background-color: rgb(22, 98, 240);
            border: 1px solid black;
            float: left;
        }
        .box2{
            height: 60vh;
            width: 40vw;
            background-color: rgb(249, 253, 8);
            border: 1px solid black;
            float: right;
        }

    </style>
</head>
<body> <div class="navbar"><header><ul>
            <li>Home</li>
            <li>About</li>
            <li>Contact us</li>
        </ul></header></div>

    <div class="container">
          </div>
    <div class="box1"></div>
    <div class="box2"></div>
</body>
</html>
# Out:
#   File "<ipython-input-1-395dee889644>", line 14
#     padding: 20px;
#               ^
# SyntaxError: invalid decimal literal
